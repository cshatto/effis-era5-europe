# %%
import os
import seaborn as sns
import pandas as pd
os.chdir('/home/cshatto/Projects/effis-era5-europe')

# %%
result_with_effis = pd.read_csv('data/processed/effis/extracted_era5_data.csv')
result_with_effis
# Out:
#                valid_time       FWI       vpd     x     y  spatial_ref  \
# 0     2017-08-01 00:00:00  3.594278  1.524315  21.8  36.9            0
# 1     2021-08-01 00:00:00  4.231096  1.799106  21.8  37.0            0
# 2     2021-08-01 00:00:00  2.441903  1.540334  21.6  38.4            0
# 3     2017-09-01 00:00:00  0.403093  0.706341  20.6  39.3            0
# 4     2000-08-01 00:00:00  2.109779  1.425464  20.5  39.8            0
# ...                   ...       ...       ...   ...   ...          ...
# 8662  2023-06-01 00:00:00  2.056034  0.796181  18.5  65.0            0
# 8663  2024-05-01 00:00:00  1.466301  0.351190  18.2  66.0            0
# 8664  2014-07-01 00:00:00  0.274933  0.653067  18.8  66.2            0
# 8665  2022-06-01 00:00:00  0.190619  0.450197  18.6  66.2            0
# 8666  2021-07-01 00:00:00  0.574937  0.653214  18.3  66.8            0
#
#       point_idx        Date CountryAbbv ForestType  AREA_HA CountryName  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Ensure figures directory exists
os.makedirs('figures', exist_ok=True)

# Assuming result_with_effis is your DataFrame from the previous script
# Extract Year as first 4 characters of YearMonth string
result_with_effis['Year'] = result_with_effis['YearMonth'].astype(str).str[:4]

# Filter out AREA_HA > 2500
filtered_df = result_with_effis[result_with_effis['AREA_HA'] <= 2500].copy()

# Get unique years in sorted order (as strings)
year_order = sorted(filtered_df['Year'].unique(), key=int)

# Set Seaborn style
sns.set(style="whitegrid")

# --- Boxplots for AREA_HA ---
# 1. AREA_HA vs ForestType
plt.figure(figsize=(10, 6))
sns.boxplot(x='ForestType', y='AREA_HA', data=filtered_df)
plt.yscale('log')  # Log scale to reduce outlier impact
plt.title('AREA_HA by Forest Type (≤ 2500 ha)')
plt.xlabel('Forest Type')
plt.ylabel('Area (ha, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/area_ha_foresttype_boxplot.png')
plt.close()

# 2. AREA_HA vs BioRegion
plt.figure(figsize=(12, 6))
sns.boxplot(x='BioRegion', y='AREA_HA', data=filtered_df)
plt.yscale('log')
plt.title('AREA_HA by BioRegion (≤ 2500 ha)')
plt.xlabel('BioRegion')
plt.ylabel('Area (ha, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/area_ha_bioregion_boxplot.png')
plt.close()

# 3. AREA_HA vs Year
plt.figure(figsize=(12, 6))
sns.boxplot(x='Year', y='AREA_HA', data=filtered_df, order=year_order)
plt.yscale('log')
plt.title('AREA_HA by Year (≤ 2500 ha)')
plt.xlabel('Year')
plt.ylabel('Area (ha, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/area_ha_year_boxplot.png')
plt.close()

# --- Boxplots for FWI ---
# 4. FWI vs ForestType
plt.figure(figsize=(10, 6))
sns.boxplot(x='ForestType', y='FWI', data=filtered_df)
plt.yscale('log')
plt.title('FWI by Forest Type')
plt.xlabel('Forest Type')
plt.ylabel('Fire Weather Index (FWI, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/fwi_foresttype_boxplot.png')
plt.close()

# 5. FWI vs BioRegion
plt.figure(figsize=(12, 6))
sns.boxplot(x='BioRegion', y='FWI', data=filtered_df)
plt.yscale('log')
plt.title('FWI by BioRegion')
plt.xlabel('BioRegion')
plt.ylabel('Fire Weather Index (FWI, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/fwi_bioregion_boxplot.png')
plt.close()

# 6. FWI vs Year
plt.figure(figsize=(12, 6))
sns.boxplot(x='Year', y='FWI', data=filtered_df, order=year_order)
plt.yscale('log')
plt.title('FWI by Year')
plt.xlabel('Year')
plt.ylabel('Fire Weather Index (FWI, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/fwi_year_boxplot.png')
plt.close()

# --- Boxplots for vpd ---
# 7. vpd vs ForestType
plt.figure(figsize=(10, 6))
sns.boxplot(x='ForestType', y='vpd', data=filtered_df)
plt.yscale('log')
plt.title('vpd by Forest Type')
plt.xlabel('Forest Type')
plt.ylabel('Vapor Pressure Deficit (vpd, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/vpd_foresttype_boxplot.png')
plt.close()

# 8. vpd vs BioRegion
plt.figure(figsize=(12, 6))
sns.boxplot(x='BioRegion', y='vpd', data=filtered_df)
plt.yscale('log')
plt.title('vpd by BioRegion')
plt.xlabel('BioRegion')
plt.ylabel('Vapor Pressure Deficit (vpd, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/vpd_bioregion_boxplot.png')
plt.close()

# 9. vpd vs Year
plt.figure(figsize=(12, 6))
sns.boxplot(x='Year', y='vpd', data=filtered_df, order=year_order)
plt.yscale('log')
plt.title('vpd by Year')
plt.xlabel('Year')
plt.ylabel('Vapor Pressure Deficit (vpd, log scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('figures/vpd_year_boxplot.png')
plt.close()

# --- New Line Plots: FWI and vpd vs AREA_HA ---
# 10. FWI vs AREA_HA
plt.figure(figsize=(10, 6))
sns.lineplot(x='FWI', y='AREA_HA', data=filtered_df)
plt.title('AREA_HA vs FWI')
plt.xlabel('Fire Weather Index (FWI)')
plt.ylabel('Area (ha)')
plt.tight_layout()
plt.savefig('figures/area_ha_vs_fwi_lineplot.png')
plt.close()

# 11. vpd vs AREA_HA
plt.figure(figsize=(10, 6))
sns.lineplot(x='vpd', y='AREA_HA', data=filtered_df)
plt.title('AREA_HA vs vpd')
plt.xlabel('Vapor Pressure Deficit (vpd)')
plt.ylabel('Area (ha)')
plt.tight_layout()
plt.savefig('figures/area_ha_vs_vpd_lineplot.png')
plt.close()

# --- Faceted Line Charts: vpd vs FWI by BioRegion and ForestType ---
# 12. vpd vs FWI by BioRegion
g1 = sns.FacetGrid(filtered_df, col='BioRegion', col_wrap=4, height=3, aspect=1.5)
g1.map(sns.lineplot, 'vpd', 'FWI')
g1.set_titles('{col_name}')
g1.set_axis_labels('Vapor Pressure Deficit (vpd)', 'Fire Weather Index (FWI)')
g1.fig.suptitle('FWI vs vpd by BioRegion', y=1.05)
g1.tight_layout()
g1.savefig('figures/fwi_vs_vpd_by_bioregion_facet.png')
plt.close()

# 13. vpd vs FWI by ForestType
g2 = sns.FacetGrid(filtered_df, col='ForestType', col_wrap=3, height=3, aspect=1.5)
g2.map(sns.lineplot, 'vpd', 'FWI')
g2.set_titles('{col_name}')
g2.set_axis_labels('Vapor Pressure Deficit (vpd)', 'Fire Weather Index (FWI)')
g2.fig.suptitle('FWI vs vpd by Forest Type', y=1.05)
g2.tight_layout()
g2.savefig('figures/fwi_vs_vpd_by_foresttype_facet.png')
plt.close()

print("All figures saved in 'figures/' folder.")
# Out:
# All figures saved in 'figures/' folder.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
import os

# Ensure figures directory exists
os.makedirs('figures', exist_ok=True)

# Use filtered_df from previous script (AREA_HA <= 2500)
# Assuming it has 'FWI', 'vpd', 'AREA_HA'

# Function to remove outliers using IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers from AREA_HA, FWI, and vpd
df_clean = filtered_df.copy()

# df_clean = remove_outliers(df_clean, 'AREA_HA')
# df_clean = remove_outliers(df_clean, 'FWI')
# df_clean = remove_outliers(df_clean, 'vpd')
print(f"Original data points: {len(filtered_df)}, After outlier removal: {len(df_clean)}")

# Remove NaN values
df_clean = df_clean.dropna(subset=['AREA_HA', 'FWI', 'vpd'])

# --- 1. Correlation Analysis ---
correlation_fwi = df_clean['FWI'].corr(df_clean['AREA_HA'])
correlation_vpd = df_clean['vpd'].corr(df_clean['AREA_HA'])
print(f"Correlation between FWI and AREA_HA: {correlation_fwi:.3f}")
print(f"Correlation between vpd and AREA_HA: {correlation_vpd:.3f}")

# --- 2. Simple Linear Regression ---
# Prepare data
X_fwi = df_clean[['FWI']].values
X_vpd = df_clean[['vpd']].values
y = df_clean['AREA_HA'].values

# Fit models
model_fwi = LinearRegression()
model_fwi.fit(X_fwi, y)
y_pred_fwi = model_fwi.predict(X_fwi)

model_vpd = LinearRegression()
model_vpd.fit(X_vpd, y)
y_pred_vpd = model_vpd.predict(X_vpd)

# Evaluate models
r2_fwi = r2_score(y, y_pred_fwi)
rmse_fwi = np.sqrt(mean_squared_error(y, y_pred_fwi))
r2_vpd = r2_score(y, y_pred_vpd)
rmse_vpd = np.sqrt(mean_squared_error(y, y_pred_vpd))

print("\nSimple Linear Regression Results (outliers removed):")
print(f"FWI: R^2 = {r2_fwi:.3f}, RMSE = {rmse_fwi:.3f}")
print(f"vpd: R^2 = {r2_vpd:.3f}, RMSE = {rmse_vpd:.3f}")

# --- 3. Multiple Linear Regression ---
X_combined = df_clean[['FWI', 'vpd']].values
model_combined = LinearRegression()
model_combined.fit(X_combined, y)
y_pred_combined = model_combined.predict(X_combined)

r2_combined = r2_score(y, y_pred_combined)
rmse_combined = np.sqrt(mean_squared_error(y, y_pred_combined))
print("\nMultiple Linear Regression (FWI + vpd, outliers removed):")
print(f"R^2 = {r2_combined:.3f}, RMSE = {rmse_combined:.3f}")
print(f"Coefficients: FWI = {model_combined.coef_[0]:.3f}, vpd = {model_combined.coef_[1]:.3f}")
print(f"Intercept: {model_combined.intercept_:.3f}")

# --- 4. Visualization ---
# Set Seaborn style
sns.set(style="whitegrid")

# Scatter plot: FWI vs AREA_HA
plt.figure(figsize=(10, 6))
sns.scatterplot(x='FWI', y='AREA_HA', data=df_clean, alpha=0.5)
plt.plot(df_clean['FWI'], y_pred_fwi, color='red', label=f'R^2 = {r2_fwi:.3f}')
plt.title('AREA_HA vs FWI with Regression Line (Outliers Removed)')
plt.xlabel('Fire Weather Index (FWI)')
plt.ylabel('Area (ha)')
plt.legend()
plt.tight_layout()
plt.savefig('figures/area_ha_vs_fwi_regression_no_outliers.png')
plt.close()

# Scatter plot: vpd vs AREA_HA
plt.figure(figsize=(10, 6))
sns.scatterplot(x='vpd', y='AREA_HA', data=df_clean, alpha=0.5)
plt.plot(df_clean['vpd'], y_pred_vpd, color='red', label=f'R^2 = {r2_vpd:.3f}')
plt.title('AREA_HA vs vpd with Regression Line (Outliers Removed)')
plt.xlabel('Vapor Pressure Deficit (vpd)')
plt.ylabel('Area (ha)')
plt.legend()
plt.tight_layout()
plt.savefig('figures/area_ha_vs_vpd_regression_no_outliers.png')
plt.close()

print("Regression plots (without outliers) saved in 'figures/' folder.")
# Out:
# Original data points: 8647, After outlier removal: 8647
# Correlation between FWI and AREA_HA: 0.117
# Correlation between vpd and AREA_HA: 0.086
#
# Simple Linear Regression Results (outliers removed):
# FWI: R^2 = 0.014, RMSE = 165.090
# vpd: R^2 = 0.007, RMSE = 165.603
#
# Multiple Linear Regression (FWI + vpd, outliers removed):
# R^2 = 0.014, RMSE = 165.085
# Coefficients: FWI = 19.417, vpd = -3.876
# Intercept: 57.704
# Regression plots (without outliers) saved in 'figures/' folder.
